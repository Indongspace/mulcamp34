# %% [markdown]
# <a href="https://colab.research.google.com/github/Indongspace/mulcamp34/blob/main/colab%EA%B3%BCdrive%EC%97%B0%EB%8F%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## google colab 과 google drive 연동

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/멀티캠퍼스 34/playground-series-s4e1/'
train = pd.read_csv(DATA_PATH + 'train.csv')
train
# Out:
#             id  CustomerId         Surname  CreditScore Geography  Gender  \
# 0            0    15674932  Okwudilichukwu          668    France    Male
# 1            1    15749177   Okwudiliolisa          627    France    Male
# 2            2    15694510           Hsueh          678    France    Male
# 3            3    15741417             Kao          581    France    Male
# 4            4    15766172       Chiemenam          716     Spain    Male
# ...        ...         ...             ...          ...       ...     ...
# 165029  165029    15667085            Meng          667     Spain  Female
# 165030  165030    15665521       Okechukwu          792    France    Male
# 165031  165031    15664752            Hsia          565    France    Male
# 165032  165032    15689614          Hsiung          554     Spain  Female
# 165033  165033    15732798         Ulyanov          850    France    Male
#
#          Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# - 파일 내보내기
# - 컬럼 임의로 몇 개 선정 후, playground에 csv로 내보내기
#  + 파일명 : result.csv

# %%
result = train.loc[:,['id','Age']]
result.to_csv("result.csv",index=False)
